# %% [markdown]
# #Titanic Projesi

# %%
##Veriye genel bakış

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# ##Tek Degiskenli Veri Analizi

# %%
## 1) Kategorik değişken analizi

# %%
train_df.describe( include = ["O"] ).T
# Out:
#          count unique                      top freq
# Name       891    891  Braund, Mr. Owen Harris    1
# Sex        891      2                     male  577
# Ticket     891    681                   347082    7
# Cabin      204    147                  B96 B98    4
# Embarked   889      3                        S  644

# %%
train_df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(train_df["Sex"])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
def category(degisken):
 print("-------------------------------------")  
 print(train_df[degisken].value_counts())
 sns.countplot(train_df[degisken])
 plt.show()

# %%
category_list =["Survived" , "Pclass" ,"Sex", "SibSp", "Parch","Embarked","Cabin"]

# %%
for i in category_list:
    category(i)
# Out:
# -------------------------------------
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# -------------------------------------
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# -------------------------------------
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# -------------------------------------
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
# -------------------------------------
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
# -------------------------------------
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# -------------------------------------
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
def clean_categorical_analysis(df):
    for col in df.select_dtypes(include="object"):
        print("\n--------------------------------------")
        print(f"Column: {col}")
        print(df[col].value_counts(dropna=False))
        print("\n")

        # Eğer kategori sayısı azsa grafik çiz
        if df[col].nunique() <= 10:
            sns.countplot(data=df, x=col)
            plt.show()
        else:
            print(f"Too many unique categories ({df[col].nunique()}). Skipping plot.")

# %%
clean_categorical_analysis(train_df)
# Out:
# --------------------------------------
# Column: Name
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64
#
#
# Too many unique categories (891). Skipping plot.
#
# --------------------------------------
# Column: Sex
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# --------------------------------------
# Column: Ticket
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64
#
#
# Too many unique categories (681). Skipping plot.
#
# --------------------------------------
# Column: Cabin
# Cabin
# NaN            687
# C23 C25 C27      4
# G6               4
# B96 B98          4
# C22 C26          3
#               ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
# Name: count, Length: 148, dtype: int64
#
#
# Too many unique categories (147). Skipping plot.
#
# --------------------------------------
# Column: Embarked
# Embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %%
## 2) Sayısal değişken analizi

# %%
def sayisal(degisken):
    plt.hist(train_df[degisken] , bins =50 )
    plt.xlabel(degisken)
    plt.ylabel("Frekans")
    plt.title("{} degisken dagılımı" .format(degisken))
    plt.show()

# %%
sayisal_list = [ "Age", "Fare", "PassengerId"]

# %%
for i in sayisal_list:
    
    sayisal(i)

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Çoklu Analiz

# %% [markdown]
# ### Kategorik değişkenlerin bağımlı değişkene etkisi

# %%
train_df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
sns.barplot(x = "Sex" , y = "Survived", data = train_df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
def kategorik_etki(degisken):
    print("{} degiskenin'in survived'e etkisi : \n ".format(degisken))
    print(train_df.groupby(degisken)["Survived"].mean())

    sns.barplot( x=degisken , y="Survived", data = train_df)
    plt.show()

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list1 =[ "Pclass", "Sex" , "SibSp", "Parch", "Embarked"]

# %%
for i in list1:
    kategorik_etki(i)
# Out:
# Pclass degiskenin'in survived'e etkisi :
#
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Sex degiskenin'in survived'e etkisi :
#
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
# SibSp degiskenin'in survived'e etkisi :
#
# SibSp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: Survived, dtype: float64
# Parch degiskenin'in survived'e etkisi :
#
# Parch
# 0    0.343658
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: Survived, dtype: float64
# Embarked degiskenin'in survived'e etkisi :
#
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
train_df[(train_df["Sex"] == "male") & (train_df["Pclass"] == 3)]["Survived"].mean()
# Out:
# 0.13544668587896252

# %%
train_df[(train_df["Sex"] == "female") & (train_df["Pclass"] == 1)]["Survived"].mean()
# Out:
# 0.9680851063829787

# %%
train_df[(train_df["Sex"] == "male") & (train_df["Pclass"] == 1)]["Survived"].mean()
# Out:
# 0.36885245901639346

# %%
sns.barplot( x= "Cabin" ,y = "Survived" , data =train_df)
# Out:
# <Axes: xlabel='Cabin', ylabel='Survived'>

# %% [markdown]
# ## 2) Sayısal değişkenlerin bağımlı değişkene etkisi

# %%
sns.jointplot(x="Age", y="Survived", data=train_df, kind="kde")

# %%
sns.jointplot(x="Age", y="Survived", data=train_df, kind="hex")

# %%
sns.jointplot(x="Age", y="Survived", data=train_df, kind="reg")

# %%
sns.jointplot(x="Fare", y="Survived", data=train_df, kind = "reg")

# %%
sns.jointplot(x="Fare", y="Survived", data=train_df, kind="kde")

# %%
sns.boxplot(x ="Pclass", y= "Fare" , data =train_df, hue = "Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
## Sayısal değişkenlerin kendi aralarındaki ilişki

# %%
numeric_df = train_df.select_dtypes(include=["int64", "float64"])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
num_df = train_df.select_dtypes(include=["int64", "float64"])
sns.pairplot(num_df)
plt.show()

# %% [markdown]
# ###FacetGrid

# %%
f = sns.FacetGrid(train_df, col ="Survived")
f.map(plt.hist, "Age")

# %%
f1 = sns.FacetGrid(train_df, row = "Pclass", col = "Survived")
f1.map(plt.hist , "Age" ,bins =20)

# %%
f2 = sns.FacetGrid(train_df, row="Embarked")
f2.map_dataframe(sns.pointplot, x="Pclass", y="Survived")
f2.add_legend()
plt.show()

# %%
sns.catplot(
    data=train_df,
    x="Pclass",
    y="Survived",
    row="Embarked",
    kind="point"
)

# %%
f3 = sns.FacetGrid(train_df, row = "Embarked", col ="Survived")
f3.map(sns.barplot,"Sex","Fare") ## sayısal değişken barplot
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
### Outlier Tespiti

# %%
train_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
def outlier(degisken):
    sns.boxplot(train_df[degisken])
    plt.show()

# %%
liste = ["Pclass","Age","SibSp","Parch","Fare"]

# %%
for i in liste:
    outlier(i)

# %%
Q1 =train_df["Fare"].quantile(0.25)
Q3 =train_df["Fare"].quantile(0.75)

IQR = Q3-Q1

alt_sinir= Q1 - 1.5*IQR
ust_sinir= Q3 + 1.5*IQR

toplam_filtre = ((train_df["Fare"] < alt_sinir)| (train_df["Fare"]> ust_sinir))
aykiri_gozlemler = train_df["Fare"][toplam_filtre]

# %%
aykiri_gozlemler .index
# Out:
# Index([  1,  27,  31,  34,  52,  61,  62,  72,  88, 102,
#        ...
#        792, 802, 820, 829, 835, 846, 849, 856, 863, 879],
#       dtype='int64', length=116)

# %%
train_df.loc[aykiri_gozlemler .index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 846                           Sage, Mr. Douglas Bullen    male   NaN      8
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 1        0  PC 17599   71.2833          C85        C
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# 34       0  PC 17604   82.1708          NaN        C
# 52       0  PC 17572   76.7292          D33        C
# ..     ...       ...       ...          ...      ...
# 846      2  CA. 2343   69.5500          NaN        S
# 849      0     17453   89.1042          C92        C
# 856      1     36928  164.8667          NaN        S
# 863      2  CA. 2343   69.5500          NaN        S
# 879      1     11767   83.1583          C50        C
#
# [116 rows x 12 columns]

# %%
def outlier(df, degiskenler):
    aykiri_indexler = []
    for i in degiskenler:
        Q1 =df[i].quantile(0.25)
        Q3 =df[i].quantile(0.75)

        IQR = Q3-Q1
        
        alt_sinir= Q1 - 1.5*IQR
        ust_sinir= Q3 + 1.5*IQR

        toplam_filtre = ((df[i] < alt_sinir)| (df[i]> ust_sinir))
        aykiri_gozlemler = df[i][toplam_filtre]
        aykiri_index= aykiri_gozlemler.index
        aykiri_indexler.extend(aykiri_index)

    aykiri_indexler = Counter(aykiri_indexler)
    ortak_indexler = [i for i, v in aykiri_indexler.items() if v > 2 ]
    return ortak_indexler
